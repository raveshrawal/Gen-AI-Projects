# %%
# Installing necessary libraries
# !pip install tensorflow
# !pip install datasets
# !pip install transformers

# Importing libraries
import tensorflow as tf
from tensorflow.keras import layers, models
import numpy as np
import matplotlib.pyplot as plt
from huggingface_hub import HfApi
from huggingface_hub import upload_folder
from huggingface_hub import hf_hub_download
from huggingface_hub import notebook_login
import os # Import the os module

# Load and preprocess the MNIST dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the sequential model
model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),
    layers.Dense(128, activation="relu"),
    layers.Dense(10, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5)

# Log in to Hugging Face Hub
notebook_login()

# Create a repository on Hugging Face Hub
repo_id = "Educosys/mnist-model"
api = HfApi()
api.create_repo(repo_id=repo_id, exist_ok=True)

# Save the model to a directory
folder_path = "my_mnist_model"
os.makedirs(folder_path, exist_ok=True) # Create the directory if it doesn't exist
model.save(os.path.join(folder_path, "mnist_model.keras")) # Save the model in the directory

# Upload the model folder to the repository
upload_folder(folder_path, repo_id=repo_id, repo_type="model")

# Download the model from the Hub
model_path = hf_hub_download(repo_id=repo_id, filename="mnist_model.keras")
model = tf.keras.models.load_model(model_path) # Use tf.keras.models.load_model
# Out:
# ...
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.8742 - loss: 0.4391
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 3ms/step - accuracy: 0.9648 - loss: 0.1222
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9775 - loss: 0.0744
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9840 - loss: 0.0540
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9863 - loss: 0.0436
# ...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-2663552591.py in <cell line: 0>()
#      48
# ...
